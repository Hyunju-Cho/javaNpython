# %%
import cv2

# %%
woyo=cv2.imread('wyw.png')
print(woyo.shape)
pltwoyo=cv2.cvtColor(woyo,cv2.COLOR_BGR2RGB)
# Out:
# (1333, 1000, 3)

# %%
import matplotlib.pyplot as plt

plt.scatter([10,20,30],[10,20,30],s=100)
plt.text(100,200,'hihihi')
plt.axis('off')
plt.imshow(pltwoyo)
plt.show()

# %%
import numpy as np

np.save('a.npy',pltwoyo)

# %%
pltwoyo=np.load('a.npy')
